# %%
import model_lib
import numpy as np
import warnings

warnings.filterwarnings('ignore', '.*output shape of zoom.*')
import pickle
import importlib
importlib.reload(model_lib)

import os
import time
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# config to train
# TODO: check Config is correct
class ProposalConfig():
    NAME = "InSegm"
    GPU_COUNT = 1
    # online training
    IMAGES_PER_GPU = 16
    STEPS_PER_EPOCH = 100
    NUM_WORKERS = 8
    PIN_MEMORY = True
    DATA_ORDER = "cw_ins"
    VALIDATION_STEPS = 20
    # including gt
    NUM_CLASSES = 81
    
    # only flips
    MEAN_PIXEL = np.array([0.485, 0.456, 0.406],dtype=np.float32).reshape(1,1,-1)
    STD_PIXEL = np.array([0.229, 0.224, 0.225],dtype=np.float32).reshape(1,1,-1)
    CLASS_NAMES = [
        'BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
        'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
        'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
        'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella',
        'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
        'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
        'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork',
        'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange',
        'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
        'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv',
        'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
        'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase',
        'scissors', 'teddy bear', 'hair drier', 'toothbrush'
    ]
    WIDTH = 224
    HEIGHT = 224
    CROP_SIZE = 224
    def __init__(self):
        self.BATCH_SIZE = self.IMAGES_PER_GPU * self.GPU_COUNT
        self.IMAGE_SHAPE = (self.WIDTH, self.HEIGHT,3)

    def display(self):
        """Display Configuration values."""
        print("\nConfigurations:")
        for a in dir(self):
            if not a.startswith("__") and not callable(getattr(self, a)):
                print("{:30} {}".format(a, getattr(self, a)))
        print("\n")

# %%
train_image_dir = "/media/Data1/interns/aravind/train2017/"
# train_image_dir = "/media/Data1/interns/aravind/val2017/"
val_image_dir = "/media/Data1/interns/aravind/val2017/"
config = ProposalConfig()
model_dir = "./models/"
train_pickle = "/media/Data1/interns/aravind/re/data/train_cwid.pickle"
# train_pickle = "/media/Data1/interns/aravind/re/data/val_cwid.pickle"
val_pickle = "/media/Data1/interns/aravind/re/data/val_cwid.pickle"

# %%
with open(train_pickle,"rb") as train_ann:
    train_cwid = pickle.load(train_ann)
with open(val_pickle,"rb") as val_ann:
    val_cwid = pickle.load(val_ann)

# %%
train_loader = model_lib.get_loader(train_cwid,config,train_image_dir)
val_loader = model_lib.get_loader(val_cwid,config,val_image_dir)
# for j in enumerate(train_loader):
#     k = j

# %%
import torch.optim as optim
import torch
import torch.nn.functional as F
net = model_lib.SimpleHGModel()

# %%
# net.vgg0.load_state_dict(torch.load("./models/split_vgg16_features_10.pt"))
# net.vgg1.load_state_dict(torch.load("./models/split_vgg16_features_32.pt"))
# pretrained_dict = torch.load(model_dir+"model_mask_vgg_2.pt")
pretrained_dict = torch.load(model_dir+"split_vgg_body_1.pt")

net_dict = net.state_dict()
pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in net_dict}

net_dict.update(pretrained_dict) 
net.load_state_dict(net_dict)

# %%
net_size = sum([i.numel() for i in net.parameters()])
def set_trainable(module,state):
    for param in module.parameters():
        param.requires_grad = state

set_trainable(net,False)
set_trainable(net.mp0,True)
set_trainable(net.mp1,True)
set_trainable(net.class_predictor,True)
for name,child in net.vgg0.named_children():
    if name[:-1] == "layer":
        [set_trainable(s.copy_filters,True) for s in child[::3]]
        [set_trainable(s.ignore_filters,False) for s in child[::3]]
        [set_trainable(s,True) for s in child[1::3]]
    elif name[:-1] == "wing_conv":
        set_trainable(child,True)
for name,child in net.vgg1.named_children():
    if name[:-1] == "layer":
        [set_trainable(s.copy_filters,True) for s in child[::3]]
        [set_trainable(s.ignore_filters,False) for s in child[::3]]
        [set_trainable(s,True) for s in child[1::3]]
    elif name[:-1] == "wing_conv":
        set_trainable(child,True)
trainable_params = filter(lambda p: p.requires_grad, net.parameters())
trainable_size = sum([i.numel() for i in trainable_params])
print(net_size,trainable_size)
net = net.cuda()
# Out:
# 57588101 20780165

# %%
# net.load_state_dict(torch.load(model_dir+"model_bce_0_2600.pt"))
optimizer = optim.SGD(filter(lambda p: p.requires_grad, net.parameters()), lr=0.001, momentum=0.9)
# optimizer = optim.Adam(filter(lambda p: p.requires_grad, net.parameters()),lr = 0.001)

iters_per_checkpoint = 60
for epoch in range(10000):  # loop over the dataset multiple times
    running_loss = 0.0
    loss1,loss2 = 0.0,0.0
    for i,data in enumerate(train_loader,0):
        batch_images,batch_impulses,batch_gt_responses,batch_one_hot = data
        batch_images,batch_impulses,batch_gt_responses,batch_one_hot = batch_images.cuda(),batch_impulses.cuda(),batch_gt_responses.cuda(),batch_one_hot.cuda()
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        pred_class,pred_masks = net([batch_images,batch_impulses])
        # we are giving no weighting for classes...
        class_loss,mask_loss = model_lib.loss_criterion(pred_class,batch_one_hot,pred_masks,batch_gt_responses,batch_impulses)
#         loss = mask_loss
#         loss = class_loss
        loss = class_loss+mask_loss
        loss.backward()
        optimizer.step()
        running_loss += loss.item(); loss1 += class_loss.item(); loss2 += mask_loss.item()
        if i % iters_per_checkpoint == 0:
            print("batch: ",i,"epoch: ",epoch, "loss: %0.5f" % (running_loss/iters_per_checkpoint))
            print("class_loss: %0.5f \t mask_loss: %0.5f"%(loss1/iters_per_checkpoint,loss2/iters_per_checkpoint))
#             torch.save(net.state_dict(),model_dir+("model_mask_vgg_%d_%d.pt")%(2,2))
            torch.save(net.state_dict(),model_dir+("split_vgg_body_1.pt"))
            running_loss = 0.0; loss1 = 0.0; loss2 = 0.0
    # print("batch: %d time:%0.3f sec" %(i, end-start)); print(loss.item())
print('Finished Training')
# Out:
# batch:  0 epoch:  0 loss: 0.00332
# class_loss: 0.00109 	 mask_loss: 0.00224
# batch:  60 epoch:  0 loss: 0.18838
# class_loss: 0.06655 	 mask_loss: 0.12183
# batch:  120 epoch:  0 loss: 0.19358
# class_loss: 0.06624 	 mask_loss: 0.12734
# batch:  180 epoch:  0 loss: 0.20070
# class_loss: 0.06589 	 mask_loss: 0.13481
# batch:  240 epoch:  0 loss: 0.19123
# class_loss: 0.06629 	 mask_loss: 0.12494
# batch:  300 epoch:  0 loss: 0.19416
# class_loss: 0.06596 	 mask_loss: 0.12820
# batch:  360 epoch:  0 loss: 0.19933
# class_loss: 0.06597 	 mask_loss: 0.13336
# batch:  420 epoch:  0 loss: 0.18298
# class_loss: 0.06611 	 mask_loss: 0.11687
# batch:  480 epoch:  0 loss: 0.19097
# class_loss: 0.06591 	 mask_loss: 0.12505
# batch:  540 epoch:  0 loss: 0.20772
# class_loss: 0.06583 	 mask_loss: 0.14189
# batch:  600 epoch:  0 loss: 0.19465
# class_loss: 0.06584 	 mask_loss: 0.12880
# batch:  660 epoch:  0 loss: 0.18876
# class_loss: 0.06610 	 mask_loss: 0.12265
# batch:  720 epoch:  0 loss: 0.21001
# class_loss: 0.06602 	 mask_loss: 0.14399
# batch:  780 epoch:  0 loss: 0.19778
# class_loss: 0.06609 	 mask_loss: 0.13168
# batch:  840 epoch:  0 loss: 0.20242
# class_loss: 0.06600 	 mask_loss: 0.13642
# batch:  900 epoch:  0 loss: 0.17573
# class_loss: 0.06569 	 mask_loss: 0.11004
# batch:  960 epoch:  0 loss: 0.19777
# class_loss: 0.06586 	 mask_loss: 0.13191
# batch:  1020 epoch:  0 loss: 0.20047
# class_loss: 0.06568 	 mask_loss: 0.13479
# batch:  1080 epoch:  0 loss: 0.18490
# class_loss: 0.06589 	 mask_loss: 0.11901
# batch:  1140 epoch:  0 loss: 0.19746
# class_loss: 0.06585 	 mask_loss: 0.13161
# batch:  1200 epoch:  0 loss: 0.19006
# class_loss: 0.06582 	 mask_loss: 0.12424
# batch:  1260 epoch:  0 loss: 0.20133
# class_loss: 0.06579 	 mask_loss: 0.13554
# batch:  1320 epoch:  0 loss: 0.18692
# class_loss: 0.06588 	 mask_loss: 0.12105
# batch:  1380 epoch:  0 loss: 0.18769
# class_loss: 0.06576 	 mask_loss: 0.12193
# batch:  1440 epoch:  0 loss: 0.18521
# class_loss: 0.06593 	 mask_loss: 0.11928
# batch:  1500 epoch:  0 loss: 0.19305
# class_loss: 0.06594 	 mask_loss: 0.12711
# batch:  1560 epoch:  0 loss: 0.20477
# class_loss: 0.06602 	 mask_loss: 0.13876
# batch:  1620 epoch:  0 loss: 0.18821
# class_loss: 0.06603 	 mask_loss: 0.12218
# batch:  1680 epoch:  0 loss: 0.19979
# class_loss: 0.06604 	 mask_loss: 0.13375
# batch:  1740 epoch:  0 loss: 0.19111
# class_loss: 0.06588 	 mask_loss: 0.12523
# batch:  1800 epoch:  0 loss: 0.19941
# class_loss: 0.06595 	 mask_loss: 0.13346
# batch:  1860 epoch:  0 loss: 0.19903
# class_loss: 0.06587 	 mask_loss: 0.13316
# batch:  1920 epoch:  0 loss: 0.18543
# class_loss: 0.06611 	 mask_loss: 0.11931
# batch:  1980 epoch:  0 loss: 0.18546
# class_loss: 0.06557 	 mask_loss: 0.11989
# batch:  2040 epoch:  0 loss: 0.20455
# class_loss: 0.06586 	 mask_loss: 0.13869
# batch:  2100 epoch:  0 loss: 0.19687
# class_loss: 0.06603 	 mask_loss: 0.13084
# batch:  2160 epoch:  0 loss: 0.18673
# class_loss: 0.06579 	 mask_loss: 0.12094
# batch:  2220 epoch:  0 loss: 0.18774
# class_loss: 0.06581 	 mask_loss: 0.12193
# batch:  2280 epoch:  0 loss: 0.18822
# class_loss: 0.06568 	 mask_loss: 0.12255
# batch:  2340 epoch:  0 loss: 0.18689
# class_loss: 0.06585 	 mask_loss: 0.12105
# batch:  2400 epoch:  0 loss: 0.18443
# class_loss: 0.06587 	 mask_loss: 0.11856
# batch:  2460 epoch:  0 loss: 0.19392
# class_loss: 0.06577 	 mask_loss: 0.12815
# batch:  2520 epoch:  0 loss: 0.18549
# class_loss: 0.06577 	 mask_loss: 0.11972
# batch:  2580 epoch:  0 loss: 0.19426
# class_loss: 0.06579 	 mask_loss: 0.12847
# batch:  2640 epoch:  0 loss: 0.19101
# class_loss: 0.06597 	 mask_loss: 0.12504
# batch:  2700 epoch:  0 loss: 0.20268
# class_loss: 0.06583 	 mask_loss: 0.13685
# batch:  2760 epoch:  0 loss: 0.19345
# class_loss: 0.06581 	 mask_loss: 0.12764
# batch:  2820 epoch:  0 loss: 0.18389
# class_loss: 0.06579 	 mask_loss: 0.11811
# batch:  2880 epoch:  0 loss: 0.18381
# class_loss: 0.06590 	 mask_loss: 0.11791
# batch:  2940 epoch:  0 loss: 0.19297
# class_loss: 0.06581 	 mask_loss: 0.12716
# batch:  3000 epoch:  0 loss: 0.20668
# class_loss: 0.06563 	 mask_loss: 0.14106
# batch:  3060 epoch:  0 loss: 0.18197
# class_loss: 0.06582 	 mask_loss: 0.11616
# batch:  3120 epoch:  0 loss: 0.18588
# class_loss: 0.06586 	 mask_loss: 0.12002
# batch:  3180 epoch:  0 loss: 0.19544
# class_loss: 0.06576 	 mask_loss: 0.12968
# batch:  3240 epoch:  0 loss: 0.20158
# class_loss: 0.06590 	 mask_loss: 0.13568
# batch:  3300 epoch:  0 loss: 0.19869
# class_loss: 0.06612 	 mask_loss: 0.13256
# batch:  3360 epoch:  0 loss: 0.18517
# class_loss: 0.06593 	 mask_loss: 0.11925
# batch:  3420 epoch:  0 loss: 0.19653
# class_loss: 0.06592 	 mask_loss: 0.13061
# batch:  3480 epoch:  0 loss: 0.17949
# class_loss: 0.06570 	 mask_loss: 0.11379
# batch:  3540 epoch:  0 loss: 0.21144
# class_loss: 0.06582 	 mask_loss: 0.14562
# batch:  3600 epoch:  0 loss: 0.18249
# class_loss: 0.06570 	 mask_loss: 0.11679
# batch:  3660 epoch:  0 loss: 0.18698
# class_loss: 0.06598 	 mask_loss: 0.12100
# batch:  3720 epoch:  0 loss: 0.19531
# class_loss: 0.06565 	 mask_loss: 0.12967
# batch:  3780 epoch:  0 loss: 0.20226
# class_loss: 0.06578 	 mask_loss: 0.13648
# batch:  3840 epoch:  0 loss: 0.18405
# class_loss: 0.06595 	 mask_loss: 0.11810
# batch:  3900 epoch:  0 loss: 0.18071
# class_loss: 0.06568 	 mask_loss: 0.11503
# batch:  3960 epoch:  0 loss: 0.18428
# class_loss: 0.06595 	 mask_loss: 0.11833
# batch:  4020 epoch:  0 loss: 0.18659
# class_loss: 0.06587 	 mask_loss: 0.12072
# batch:  4080 epoch:  0 loss: 0.19510
# class_loss: 0.06584 	 mask_loss: 0.12926
# batch:  4140 epoch:  0 loss: 0.17845
# class_loss: 0.06571 	 mask_loss: 0.11273
# batch:  4200 epoch:  0 loss: 0.20627
# class_loss: 0.06585 	 mask_loss: 0.14042
# batch:  4260 epoch:  0 loss: 0.18996
# class_loss: 0.06603 	 mask_loss: 0.12392
# batch:  4320 epoch:  0 loss: 0.18428
# class_loss: 0.06560 	 mask_loss: 0.11868
# batch:  4380 epoch:  0 loss: 0.19521
# class_loss: 0.06575 	 mask_loss: 0.12946
# batch:  4440 epoch:  0 loss: 0.18344
# class_loss: 0.06563 	 mask_loss: 0.11781
# batch:  4500 epoch:  0 loss: 0.18633
# class_loss: 0.06555 	 mask_loss: 0.12078
# batch:  4560 epoch:  0 loss: 0.19722
# class_loss: 0.06575 	 mask_loss: 0.13147
# batch:  4620 epoch:  0 loss: 0.18556
# class_loss: 0.06576 	 mask_loss: 0.11980
# batch:  4680 epoch:  0 loss: 0.18677
# class_loss: 0.06569 	 mask_loss: 0.12109
# batch:  4740 epoch:  0 loss: 0.20048
# class_loss: 0.06576 	 mask_loss: 0.13472
# batch:  4800 epoch:  0 loss: 0.20373
# class_loss: 0.06524 	 mask_loss: 0.13849
# batch:  4860 epoch:  0 loss: 0.19379
# class_loss: 0.06589 	 mask_loss: 0.12790
# batch:  4920 epoch:  0 loss: 0.17875
# class_loss: 0.06594 	 mask_loss: 0.11281
# batch:  4980 epoch:  0 loss: 0.20397
# class_loss: 0.06573 	 mask_loss: 0.13824
# batch:  5040 epoch:  0 loss: 0.19400
# class_loss: 0.06557 	 mask_loss: 0.12842
# batch:  5100 epoch:  0 loss: 0.17933
# class_loss: 0.06586 	 mask_loss: 0.11347
# batch:  5160 epoch:  0 loss: 0.19755
# class_loss: 0.06561 	 mask_loss: 0.13194
# batch:  5220 epoch:  0 loss: 0.18786
# class_loss: 0.06579 	 mask_loss: 0.12208
# batch:  5280 epoch:  0 loss: 0.19744
# class_loss: 0.06582 	 mask_loss: 0.13162
# batch:  5340 epoch:  0 loss: 0.19408
# class_loss: 0.06567 	 mask_loss: 0.12841
# batch:  5400 epoch:  0 loss: 0.19829
# class_loss: 0.06545 	 mask_loss: 0.13284
# batch:  5460 epoch:  0 loss: 0.20277
# class_loss: 0.06569 	 mask_loss: 0.13708
# batch:  5520 epoch:  0 loss: 0.18534
# class_loss: 0.06578 	 mask_loss: 0.11956
# batch:  5580 epoch:  0 loss: 0.19636
# class_loss: 0.06542 	 mask_loss: 0.13094
# batch:  5640 epoch:  0 loss: 0.19600
# class_loss: 0.06567 	 mask_loss: 0.13033
# batch:  5700 epoch:  0 loss: 0.18050
# class_loss: 0.06556 	 mask_loss: 0.11494
# batch:  5760 epoch:  0 loss: 0.19488
# class_loss: 0.06598 	 mask_loss: 0.12890
# batch:  5820 epoch:  0 loss: 0.18923
# class_loss: 0.06531 	 mask_loss: 0.12391
# batch:  5880 epoch:  0 loss: 0.20116
# class_loss: 0.06549 	 mask_loss: 0.13568
# batch:  5940 epoch:  0 loss: 0.18392
# class_loss: 0.06584 	 mask_loss: 0.11808
# batch:  6000 epoch:  0 loss: 0.19428
# class_loss: 0.06566 	 mask_loss: 0.12862
# batch:  6060 epoch:  0 loss: 0.19148
# class_loss: 0.06557 	 mask_loss: 0.12590
# batch:  6120 epoch:  0 loss: 0.18146
# class_loss: 0.06543 	 mask_loss: 0.11602
# batch:  6180 epoch:  0 loss: 0.19499
# class_loss: 0.06593 	 mask_loss: 0.12906
# batch:  6240 epoch:  0 loss: 0.18900
# class_loss: 0.06536 	 mask_loss: 0.12365
# batch:  6300 epoch:  0 loss: 0.19993
# class_loss: 0.06564 	 mask_loss: 0.13429
# batch:  6360 epoch:  0 loss: 0.21360
# class_loss: 0.06559 	 mask_loss: 0.14801
# batch:  6420 epoch:  0 loss: 0.18810
# class_loss: 0.06568 	 mask_loss: 0.12241
# batch:  6480 epoch:  0 loss: 0.20183
# class_loss: 0.06580 	 mask_loss: 0.13603
# batch:  6540 epoch:  0 loss: 0.20186
# class_loss: 0.06577 	 mask_loss: 0.13610
# batch:  6600 epoch:  0 loss: 0.17934
# class_loss: 0.06563 	 mask_loss: 0.11371
# batch:  6660 epoch:  0 loss: 0.18708
# class_loss: 0.06585 	 mask_loss: 0.12122
# batch:  6720 epoch:  0 loss: 0.18477
# class_loss: 0.06553 	 mask_loss: 0.11924
# batch:  6780 epoch:  0 loss: 0.18324
# class_loss: 0.06522 	 mask_loss: 0.11802
# batch:  6840 epoch:  0 loss: 0.18518
# class_loss: 0.06557 	 mask_loss: 0.11961
# batch:  6900 epoch:  0 loss: 0.17614
# class_loss: 0.06567 	 mask_loss: 0.11047
# batch:  6960 epoch:  0 loss: 0.18674
# class_loss: 0.06565 	 mask_loss: 0.12109
# batch:  7020 epoch:  0 loss: 0.18934
# class_loss: 0.06529 	 mask_loss: 0.12405
# batch:  7080 epoch:  0 loss: 0.19171
# class_loss: 0.06567 	 mask_loss: 0.12604
# batch:  7140 epoch:  0 loss: 0.20214
# class_loss: 0.06552 	 mask_loss: 0.13661
# batch:  7200 epoch:  0 loss: 0.18077
# class_loss: 0.06535 	 mask_loss: 0.11542
# batch:  7260 epoch:  0 loss: 0.19871
# class_loss: 0.06536 	 mask_loss: 0.13335
# batch:  7320 epoch:  0 loss: 0.18616
# class_loss: 0.06559 	 mask_loss: 0.12056
# batch:  7380 epoch:  0 loss: 0.18459
# class_loss: 0.06552 	 mask_loss: 0.11907
# batch:  7440 epoch:  0 loss: 0.17658
# class_loss: 0.06544 	 mask_loss: 0.11114
# batch:  7500 epoch:  0 loss: 0.16657
# class_loss: 0.06535 	 mask_loss: 0.10122
# batch:  7560 epoch:  0 loss: 0.19379
# class_loss: 0.06541 	 mask_loss: 0.12837
# batch:  7620 epoch:  0 loss: 0.19848
# class_loss: 0.06535 	 mask_loss: 0.13312
# batch:  7680 epoch:  0 loss: 0.18891
# class_loss: 0.06533 	 mask_loss: 0.12358
# batch:  7740 epoch:  0 loss: 0.19605
# class_loss: 0.06554 	 mask_loss: 0.13052
# batch:  7800 epoch:  0 loss: 0.18495
# class_loss: 0.06547 	 mask_loss: 0.11948
# batch:  7860 epoch:  0 loss: 0.18366
# class_loss: 0.06554 	 mask_loss: 0.11811
# batch:  7920 epoch:  0 loss: 0.19178
# class_loss: 0.06580 	 mask_loss: 0.12599
# batch:  7980 epoch:  0 loss: 0.19043
# class_loss: 0.06550 	 mask_loss: 0.12492
# batch:  8040 epoch:  0 loss: 0.18747
# class_loss: 0.06558 	 mask_loss: 0.12189
# batch:  8100 epoch:  0 loss: 0.18287
# class_loss: 0.06539 	 mask_loss: 0.11747
# batch:  8160 epoch:  0 loss: 0.18373
# class_loss: 0.06545 	 mask_loss: 0.11828
# batch:  8220 epoch:  0 loss: 0.17891
# class_loss: 0.06535 	 mask_loss: 0.11357
# batch:  8280 epoch:  0 loss: 0.19375
# class_loss: 0.06542 	 mask_loss: 0.12833
# batch:  8340 epoch:  0 loss: 0.18023
# class_loss: 0.06554 	 mask_loss: 0.11469
# batch:  8400 epoch:  0 loss: 0.18166
# class_loss: 0.06512 	 mask_loss: 0.11654
# batch:  8460 epoch:  0 loss: 0.17822
# class_loss: 0.06548 	 mask_loss: 0.11274
# batch:  8520 epoch:  0 loss: 0.19272
# class_loss: 0.06523 	 mask_loss: 0.12749
# batch:  8580 epoch:  0 loss: 0.18338
# class_loss: 0.06523 	 mask_loss: 0.11815
# batch:  8640 epoch:  0 loss: 0.17306
# class_loss: 0.06539 	 mask_loss: 0.10767
# batch:  8700 epoch:  0 loss: 0.19554
# class_loss: 0.06570 	 mask_loss: 0.12984
# batch:  8760 epoch:  0 loss: 0.19436
# class_loss: 0.06529 	 mask_loss: 0.12907
# batch:  8820 epoch:  0 loss: 0.17684
# class_loss: 0.06529 	 mask_loss: 0.11155
# batch:  8880 epoch:  0 loss: 0.17374
# class_loss: 0.06534 	 mask_loss: 0.10840
# batch:  8940 epoch:  0 loss: 0.18594
# class_loss: 0.06557 	 mask_loss: 0.12037
# batch:  9000 epoch:  0 loss: 0.18916
# class_loss: 0.06534 	 mask_loss: 0.12382
# batch:  9060 epoch:  0 loss: 0.18810
# class_loss: 0.06532 	 mask_loss: 0.12279
# batch:  9120 epoch:  0 loss: 0.18445
# class_loss: 0.06529 	 mask_loss: 0.11916
# batch:  9180 epoch:  0 loss: 0.18895
# class_loss: 0.06509 	 mask_loss: 0.12385
# batch:  9240 epoch:  0 loss: 0.19542
# class_loss: 0.06539 	 mask_loss: 0.13003
# batch:  9300 epoch:  0 loss: 0.19304
# class_loss: 0.06536 	 mask_loss: 0.12768
# batch:  9360 epoch:  0 loss: 0.19080
# class_loss: 0.06525 	 mask_loss: 0.12554
# batch:  9420 epoch:  0 loss: 0.19601
# class_loss: 0.06524 	 mask_loss: 0.13077
# batch:  9480 epoch:  0 loss: 0.20550
# class_loss: 0.06563 	 mask_loss: 0.13987
# batch:  9540 epoch:  0 loss: 0.20116
# class_loss: 0.06559 	 mask_loss: 0.13556
# batch:  9600 epoch:  0 loss: 0.18376
# class_loss: 0.06562 	 mask_loss: 0.11813
# batch:  9660 epoch:  0 loss: 0.18294
# class_loss: 0.06514 	 mask_loss: 0.11780
# batch:  9720 epoch:  0 loss: 0.17925
# class_loss: 0.06525 	 mask_loss: 0.11400
# batch:  9780 epoch:  0 loss: 0.19067
# class_loss: 0.06538 	 mask_loss: 0.12528
# batch:  9840 epoch:  0 loss: 0.17957
# class_loss: 0.06500 	 mask_loss: 0.11456
# batch:  9900 epoch:  0 loss: 0.18381
# class_loss: 0.06528 	 mask_loss: 0.11853
# batch:  9960 epoch:  0 loss: 0.18191
# class_loss: 0.06534 	 mask_loss: 0.11657
# batch:  10020 epoch:  0 loss: 0.18324
# class_loss: 0.06515 	 mask_loss: 0.11809
# batch:  10080 epoch:  0 loss: 0.20348
# class_loss: 0.06526 	 mask_loss: 0.13822
# batch:  10140 epoch:  0 loss: 0.19605
# class_loss: 0.06522 	 mask_loss: 0.13084
# batch:  10200 epoch:  0 loss: 0.19072
# class_loss: 0.06519 	 mask_loss: 0.12553
# batch:  10260 epoch:  0 loss: 0.18155
# class_loss: 0.06505 	 mask_loss: 0.11650
# batch:  10320 epoch:  0 loss: 0.19401
# class_loss: 0.06507 	 mask_loss: 0.12894
# batch:  10380 epoch:  0 loss: 0.17732
# class_loss: 0.06523 	 mask_loss: 0.11209
# batch:  10440 epoch:  0 loss: 0.18118
# class_loss: 0.06518 	 mask_loss: 0.11601
# batch:  10500 epoch:  0 loss: 0.18452
# class_loss: 0.06503 	 mask_loss: 0.11949
# batch:  10560 epoch:  0 loss: 0.18391
# class_loss: 0.06501 	 mask_loss: 0.11891
# batch:  10620 epoch:  0 loss: 0.18793
# class_loss: 0.06521 	 mask_loss: 0.12273
# batch:  10680 epoch:  0 loss: 0.18176
# class_loss: 0.06513 	 mask_loss: 0.11663
# batch:  10740 epoch:  0 loss: 0.19836
# class_loss: 0.06508 	 mask_loss: 0.13328
# batch:  10800 epoch:  0 loss: 0.19080
# class_loss: 0.06541 	 mask_loss: 0.12539
# batch:  10860 epoch:  0 loss: 0.17983
# class_loss: 0.06508 	 mask_loss: 0.11474
# batch:  10920 epoch:  0 loss: 0.19166
# class_loss: 0.06524 	 mask_loss: 0.12642
# batch:  10980 epoch:  0 loss: 0.20529
# class_loss: 0.06530 	 mask_loss: 0.13999
# batch:  11040 epoch:  0 loss: 0.19311
# class_loss: 0.06495 	 mask_loss: 0.12816
# batch:  11100 epoch:  0 loss: 0.19252
# class_loss: 0.06501 	 mask_loss: 0.12751
# batch:  11160 epoch:  0 loss: 0.19153
# class_loss: 0.06514 	 mask_loss: 0.12639
# batch:  11220 epoch:  0 loss: 0.17712
# class_loss: 0.06499 	 mask_loss: 0.11212
# batch:  11280 epoch:  0 loss: 0.18323
# class_loss: 0.06521 	 mask_loss: 0.11801
# batch:  11340 epoch:  0 loss: 0.19679
# class_loss: 0.06502 	 mask_loss: 0.13177
# batch:  11400 epoch:  0 loss: 0.19309
# class_loss: 0.06525 	 mask_loss: 0.12784
# batch:  11460 epoch:  0 loss: 0.18439
# class_loss: 0.06527 	 mask_loss: 0.11913
# batch:  11520 epoch:  0 loss: 0.17428
# class_loss: 0.06496 	 mask_loss: 0.10932
# batch:  11580 epoch:  0 loss: 0.18476
# class_loss: 0.06487 	 mask_loss: 0.11988
# batch:  11640 epoch:  0 loss: 0.19392
# class_loss: 0.06525 	 mask_loss: 0.12867
# batch:  11700 epoch:  0 loss: 0.18162
# class_loss: 0.06492 	 mask_loss: 0.11670
# batch:  11760 epoch:  0 loss: 0.18954
# class_loss: 0.06498 	 mask_loss: 0.12456
# batch:  11820 epoch:  0 loss: 0.19152
# class_loss: 0.06470 	 mask_loss: 0.12682
# batch:  11880 epoch:  0 loss: 0.19486
# class_loss: 0.06502 	 mask_loss: 0.12983
# batch:  11940 epoch:  0 loss: 0.17863
# class_loss: 0.06503 	 mask_loss: 0.11361
# batch:  12000 epoch:  0 loss: 0.19502
# class_loss: 0.06492 	 mask_loss: 0.13009
# batch:  12060 epoch:  0 loss: 0.18306
# class_loss: 0.06504 	 mask_loss: 0.11803
# batch:  12120 epoch:  0 loss: 0.18554
# class_loss: 0.06478 	 mask_loss: 0.12076
# batch:  12180 epoch:  0 loss: 0.19253
# class_loss: 0.06510 	 mask_loss: 0.12743
# batch:  12240 epoch:  0 loss: 0.19080
# class_loss: 0.06517 	 mask_loss: 0.12563
# batch:  12300 epoch:  0 loss: 0.18169
# class_loss: 0.06483 	 mask_loss: 0.11686
# batch:  12360 epoch:  0 loss: 0.18846
# class_loss: 0.06502 	 mask_loss: 0.12343
# batch:  12420 epoch:  0 loss: 0.19128
# class_loss: 0.06476 	 mask_loss: 0.12652
# batch:  12480 epoch:  0 loss: 0.18550
# class_loss: 0.06462 	 mask_loss: 0.12088
# batch:  12540 epoch:  0 loss: 0.19347
# class_loss: 0.06468 	 mask_loss: 0.12879
# batch:  12600 epoch:  0 loss: 0.18612
# class_loss: 0.06505 	 mask_loss: 0.12107
# batch:  12660 epoch:  0 loss: 0.18957
# class_loss: 0.06498 	 mask_loss: 0.12459
# batch:  12720 epoch:  0 loss: 0.18641
# class_loss: 0.06521 	 mask_loss: 0.12119
# batch:  12780 epoch:  0 loss: 0.18605
# class_loss: 0.06480 	 mask_loss: 0.12126
# batch:  12840 epoch:  0 loss: 0.18166
# class_loss: 0.06473 	 mask_loss: 0.11693
# batch:  12900 epoch:  0 loss: 0.18611
# class_loss: 0.06508 	 mask_loss: 0.12104
# batch:  12960 epoch:  0 loss: 0.18139
# class_loss: 0.06461 	 mask_loss: 0.11678
# batch:  13020 epoch:  0 loss: 0.17523
# class_loss: 0.06483 	 mask_loss: 0.11040
# batch:  13080 epoch:  0 loss: 0.18983
# class_loss: 0.06493 	 mask_loss: 0.12490
# batch:  13140 epoch:  0 loss: 0.18790
# class_loss: 0.06494 	 mask_loss: 0.12296
# batch:  13200 epoch:  0 loss: 0.17819
# class_loss: 0.06439 	 mask_loss: 0.11380
# batch:  13260 epoch:  0 loss: 0.18290
# class_loss: 0.06471 	 mask_loss: 0.11819
# batch:  13320 epoch:  0 loss: 0.17496
# class_loss: 0.06473 	 mask_loss: 0.11023
# batch:  13380 epoch:  0 loss: 0.18807
# class_loss: 0.06515 	 mask_loss: 0.12292
# batch:  13440 epoch:  0 loss: 0.18587
# class_loss: 0.06455 	 mask_loss: 0.12132
# batch:  13500 epoch:  0 loss: 0.19138
# class_loss: 0.06469 	 mask_loss: 0.12669
# batch:  13560 epoch:  0 loss: 0.17909
# class_loss: 0.06432 	 mask_loss: 0.11477
# batch:  13620 epoch:  0 loss: 0.18604
# class_loss: 0.06453 	 mask_loss: 0.12150
# batch:  13680 epoch:  0 loss: 0.18156
# class_loss: 0.06464 	 mask_loss: 0.11691
# batch:  13740 epoch:  0 loss: 0.18688
# class_loss: 0.06489 	 mask_loss: 0.12199
# batch:  13800 epoch:  0 loss: 0.18680
# class_loss: 0.06490 	 mask_loss: 0.12190
# batch:  13860 epoch:  0 loss: 0.19072
# class_loss: 0.06477 	 mask_loss: 0.12594
# batch:  13920 epoch:  0 loss: 0.19180
# class_loss: 0.06532 	 mask_loss: 0.12648
# batch:  13980 epoch:  0 loss: 0.18782
# class_loss: 0.06468 	 mask_loss: 0.12314
# batch:  14040 epoch:  0 loss: 0.19634
# class_loss: 0.06481 	 mask_loss: 0.13153
# batch:  14100 epoch:  0 loss: 0.17913
# class_loss: 0.06466 	 mask_loss: 0.11446
# batch:  14160 epoch:  0 loss: 0.17985
# class_loss: 0.06478 	 mask_loss: 0.11507
# batch:  14220 epoch:  0 loss: 0.19785
# class_loss: 0.06468 	 mask_loss: 0.13317
# batch:  14280 epoch:  0 loss: 0.18991
# class_loss: 0.06473 	 mask_loss: 0.12518
# batch:  14340 epoch:  0 loss: 0.17659
# class_loss: 0.06467 	 mask_loss: 0.11192
# batch:  14400 epoch:  0 loss: 0.18872
# class_loss: 0.06478 	 mask_loss: 0.12395
# batch:  14460 epoch:  0 loss: 0.19415
# class_loss: 0.06478 	 mask_loss: 0.12937
# batch:  14520 epoch:  0 loss: 0.18619
# class_loss: 0.06477 	 mask_loss: 0.12142
# batch:  14580 epoch:  0 loss: 0.18579
# class_loss: 0.06449 	 mask_loss: 0.12130
# batch:  14640 epoch:  0 loss: 0.18756
# class_loss: 0.06424 	 mask_loss: 0.12332
# batch:  14700 epoch:  0 loss: 0.17718
# class_loss: 0.06466 	 mask_loss: 0.11251
# batch:  14760 epoch:  0 loss: 0.19619
# class_loss: 0.06456 	 mask_loss: 0.13162
# batch:  14820 epoch:  0 loss: 0.18979
# class_loss: 0.06455 	 mask_loss: 0.12524
# batch:  14880 epoch:  0 loss: 0.18419
# class_loss: 0.06460 	 mask_loss: 0.11958
# batch:  14940 epoch:  0 loss: 0.18536
# class_loss: 0.06449 	 mask_loss: 0.12087
# batch:  15000 epoch:  0 loss: 0.17442
# class_loss: 0.06433 	 mask_loss: 0.11009
# batch:  15060 epoch:  0 loss: 0.19314
# class_loss: 0.06475 	 mask_loss: 0.12839
# batch:  15120 epoch:  0 loss: 0.19004
# class_loss: 0.06463 	 mask_loss: 0.12541
# batch:  15180 epoch:  0 loss: 0.18632
# class_loss: 0.06441 	 mask_loss: 0.12191
# batch:  15240 epoch:  0 loss: 0.18250
# class_loss: 0.06464 	 mask_loss: 0.11787
# batch:  15300 epoch:  0 loss: 0.20350
# class_loss: 0.06471 	 mask_loss: 0.13878
# batch:  15360 epoch:  0 loss: 0.19181
# class_loss: 0.06478 	 mask_loss: 0.12703
# batch:  15420 epoch:  0 loss: 0.17641
# class_loss: 0.06455 	 mask_loss: 0.11185
# batch:  15480 epoch:  0 loss: 0.18394
# class_loss: 0.06463 	 mask_loss: 0.11931
# batch:  15540 epoch:  0 loss: 0.19489
# class_loss: 0.06459 	 mask_loss: 0.13031
# batch:  15600 epoch:  0 loss: 0.18632
# class_loss: 0.06442 	 mask_loss: 0.12190
# batch:  15660 epoch:  0 loss: 0.18080
# class_loss: 0.06431 	 mask_loss: 0.11650
# batch:  15720 epoch:  0 loss: 0.18904
# class_loss: 0.06453 	 mask_loss: 0.12451
# batch:  15780 epoch:  0 loss: 0.17878
# class_loss: 0.06458 	 mask_loss: 0.11420
# batch:  15840 epoch:  0 loss: 0.18481
# class_loss: 0.06451 	 mask_loss: 0.12030
# batch:  15900 epoch:  0 loss: 0.18420
# class_loss: 0.06434 	 mask_loss: 0.11985
# batch:  15960 epoch:  0 loss: 0.19443
# class_loss: 0.06456 	 mask_loss: 0.12987
# batch:  16020 epoch:  0 loss: 0.18516
# class_loss: 0.06453 	 mask_loss: 0.12063
# batch:  16080 epoch:  0 loss: 0.19376
# class_loss: 0.06468 	 mask_loss: 0.12907
# batch:  16140 epoch:  0 loss: 0.19976
# class_loss: 0.06443 	 mask_loss: 0.13533
# batch:  16200 epoch:  0 loss: 0.18580
# class_loss: 0.06425 	 mask_loss: 0.12155
# batch:  16260 epoch:  0 loss: 0.19112
# class_loss: 0.06431 	 mask_loss: 0.12681
# batch:  16320 epoch:  0 loss: 0.19035
# class_loss: 0.06432 	 mask_loss: 0.12603
# batch:  16380 epoch:  0 loss: 0.17828
# class_loss: 0.06404 	 mask_loss: 0.11423
# batch:  16440 epoch:  0 loss: 0.19280
# class_loss: 0.06415 	 mask_loss: 0.12865
# batch:  16500 epoch:  0 loss: 0.20022
# class_loss: 0.06427 	 mask_loss: 0.13595
# batch:  16560 epoch:  0 loss: 0.18842
# class_loss: 0.06430 	 mask_loss: 0.12412
# batch:  16620 epoch:  0 loss: 0.18106
# class_loss: 0.06458 	 mask_loss: 0.11648
# batch:  16680 epoch:  0 loss: 0.18400
# class_loss: 0.06482 	 mask_loss: 0.11918
# batch:  16740 epoch:  0 loss: 0.17017
# class_loss: 0.06411 	 mask_loss: 0.10606
# batch:  16800 epoch:  0 loss: 0.17909
# class_loss: 0.06436 	 mask_loss: 0.11473
# batch:  16860 epoch:  0 loss: 0.19194
# class_loss: 0.06468 	 mask_loss: 0.12726
